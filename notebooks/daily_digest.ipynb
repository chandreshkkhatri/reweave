# %% [markdown]
# # Daily Digest Workflow
#
# Generate short-form vertical videos (1080x1920) summarizing a topic with:
# - AI-generated background image
# - Animated bullet points appearing one-by-one
# - TTS narration audio
#
# Perfect for TikTok, Instagram Reels, and YouTube Shorts.
#
# ## Prerequisites
# - Set `GEMINI_API_KEY` in your `.env` file
# - Install dependencies: `pip install reweave`

# %%
from reweave.workflows.daily_digest_workflow import DailyDigestWorkflow

workflow = DailyDigestWorkflow()

# %%
# Generate an AI news digest
result = workflow.generate_digest(
    content_id="ai-news-2026-02-06",
    topic="Latest AI breakthroughs and announcements this week"
)

print(f"Title: {result['digest']['title']}")
print(f"Bullets: {len(result['digest']['bullets'])}")
print(f"\nVideo: {result['video']}")

# %%
# Generate a space exploration update
result = workflow.generate_digest(
    content_id="space-update-001",
    topic="Space exploration milestones and upcoming launches"
)

# %%
# Generate a history digest
result = workflow.generate_digest(
    content_id="history-today-001",
    topic="Notable historical events that happened on February 6th"
)
