# %% [markdown]
# ### Generate a graphical story
#
# Creates an illustrated story video from a text topic using Gemini for text/image generation and gTTS for narration.
#
# **Prerequisites:** Set `GEMINI_API_KEY` in your `.env` file.

# %%
from reweave.workflows.graphical_story_workflow import GraphicalStoryWorkflow

# %%
graphical_story_instance = GraphicalStoryWorkflow()

# %%
id = "tortoise_hare_1"
title = '_1	The Tortoise and the Hare'
instructions = (
    "Create a graphical story based on the fable 'The Tortoise and the Hare'.",
    "Classic fable, warm watercolour"
)

# %%
graphical_story_instance.create_story(id, title)
graphical_story_instance.generate_script(id)
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# Cell In[8], line 2
#       1 graphical_story_instance.create_story(id, title)
# ----> 2 graphical_story_instance.generate_script(id)
#
# File ~/code/reweave/reweave/workflows/graphical_story_workflow/graphical_story_workflow.py:35, in GraphicalStoryWorkflow.generate_script(self, content_id)
#      31 """
#      32 Generate script
#      33 """
#      34 story = self.graphical_story_repo.get_story(content_id)
# ---> 35 script = self.script_builder.generate_script(story)
#      36 self.graphical_story_repo.create_script(content_id, script)
#
# File ~/code/reweave/reweave/workflows/graphical_story_workflow/story_builder.py:118, in ScriptBuilder.generate_script(self, story)
#      49 prompt = f"""
#      50 You are a helpful screenwriter. Use the story provided below to write a script.
#      51
# ...

# %%
graphical_story_instance.generate_footages(id)

# %%
graphical_story_instance.generate_final_video(id)
